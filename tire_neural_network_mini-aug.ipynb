# %%
import numpy
import scipy.special
import matplotlib.pyplot
# %matplotlib inline
from skimage import transform,io
import glob

# %%
# neural network class definition
class neuralNetwork:
    
    
    # initialise the neural network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        # set number of nodes in each input, hidden, output layer
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        
        # link weight matrices, wih and who
        # weights inside the arrays are w_i_j, where link is from node i to node j in the next layer
        # w11 w21
        # w12 w22 etc 
        self.wih = numpy.random.normal(0.0, pow(self.inodes, -0.5), (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.onodes, self.hnodes))

        # learning rate
        self.lr = learningrate
        
        # activation function is the sigmoid function
        self.activation_function = lambda x: scipy.special.expit(x)
        
        pass

    
    # train the neural network
    def train(self, inputs_list, targets_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        targets = numpy.array(targets_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        
        # output layer error is the (target - actual)
        output_errors = targets - final_outputs
        # hidden layer error is the output_errors, split by weights, recombined at hidden nodes
        hidden_errors = numpy.dot(self.who.T, output_errors) 
        
        # update the weights for the links between the hidden and output layers
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)), numpy.transpose(hidden_outputs))
        
        # update the weights for the links between the input and hidden layers
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), numpy.transpose(inputs))
        
        pass

    
    # query the neural network
    def query(self, inputs_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs

# %%
# number of input, hidden and output nodes
input_nodes = 784
hidden_nodes = 200
# output_nodes = 10
# summer 12 + winter 12 + other 1
output_nodes = 25

# learning rate
learning_rate = 0.1

# create instance of neural network
n = neuralNetwork(input_nodes,hidden_nodes,output_nodes, learning_rate)

# %%
items = 208
train_dataset = []
fig = matplotlib.pyplot.figure(figsize=(20,  items * 2))
for image_file_name in glob.glob('./DATA/TRAIN_mini/*/*'):
    # print(image_file_name)
    line = str(image_file_name[13:])
    line = line[:line.find('/')]
    # print(line)
    if line  == "FRONTNANAMEFIT": label = 0
    elif line  == "FRONTTATEFAR": label = 1
    elif line  == "FRONTTATEFITBOTTOM": label = 2
    elif line  == "FRONTTATEFITCENTER": label = 3
    elif line  == "FRONTTATEFITLEFT": label = 4
    elif line  == "FRONTTATEFITRIGHT": label = 5
    elif line  == "FRONTTATEFITTOP": label = 6
    elif line  == "FRONTTATEJUSTCENTER": label = 7
    elif line  == "FRONTTATENEAR": label = 8
    elif line  == "FRONTYOKOFAR": label = 9
    elif line  == "FRONTYOKOFIT": label = 10
    elif line  == "NANAMETATEFIT": label = 11
    elif line  == "WINTERFRONTNANAMEFIT": label = 12
    elif line  == "WINTERFRONTTATEFAR": label = 13
    elif line  == "WINTERFRONTTATEFITBOTTOM": label = 14
    elif line  == "WINTERFRONTTATEFITCENTER": label = 15
    elif line  == "WINTERFRONTTATEFITLEFT": label = 16
    elif line  == "WINTERFRONTTATEFITRIGHT": label = 17
    elif line  == "WINTERFRONTTATEFITTOP": label = 18
    elif line  == "WINTERFRONTTATEJUSTCENTER": label = 19
    elif line  == "WINTERFRONTTATENEAR": label = 20
    elif line  == "WINTERFRONTYOKOFAR": label = 21
    elif line  == "WINTERFRONTYOKOFIT": label = 22
    elif line  == "WINTERNANAMETATEFIT": label = 23
    else: label = 24
    # print(label)
    img = transform.resize(io.imread(image_file_name, as_gray=True), (28, 28), mode='symmetric', preserve_range=True)
    # matplotlib.pyplot.imshow(img, cmap='Greys', interpolation='None')
    ax = fig.add_subplot(200, 5, len(train_dataset) + 1)
    ax.imshow(img,  cmap='Greys', interpolation='None')
    ax.set_axis_off()
    ax.set_title(str(len(train_dataset)))
    img_data = img.reshape(784)
    img_data = (img_data / 255.0 * 0.99) + 0.01
    # print(numpy.min(img_data))
    # print(numpy.max(img_data))
    record = numpy.append(label,img_data)
    train_dataset.append(record)
    print(str(len(train_dataset) - 1) + ", " + str(label) +", " + image_file_name) 

    pass
matplotlib.pyplot.show()
# Out:
# 0, 24, ./DATA/TRAIN_mini/02838_Human_leg_resized/17064023044_57951e7e59_z.jpg.jpg
# 1, 24, ./DATA/TRAIN_mini/02838_Human_leg_resized/14652853751_596e01e105_z.jpg.jpg
# 75, 24, ./DATA/TRAIN_mini/FRONTYOKOFIT/6f181f522fd49ce9b6de551660cb74349bfdc250_R180_B2T_RESIZED_R90.jpg
# 76, 24, ./DATA/TRAIN_mini/FRONTTATEFAR/7cfd83eef92ea1f58f6e33a322b360a3ada32215_224_70.jpg
# 77, 24, ./DATA/TRAIN_mini/FRONTTATEFAR/08a6cfcb6ac3be28ab358606f45efe44ebe40a83_224_70.jpg
# 78, 24, ./DATA/TRAIN_mini/FRONTTATEFAR/75107147661a53fa37324a8be7bdc4fc2837786f_R90_TCC80_RESIZED.jpg
# 79, 24, ./DATA/TRAIN_mini/FRONTTATEFAR/c61819e1587b44862b205645cb49248a5834ec9d_224_70.jpg
# 80, 24, ./DATA/TRAIN_mini/FRONTTATEFITTOP/295ce32d9fb1179547e55c04669d70f08e1f67bf_R180_B2T_RESIZED.jpg
# 81, 24, ./DATA/TRAIN_mini/FRONTTATEFITTOP/11a6f26b007e629cff1ca9f2b523e1c5ff70fb41_224_70.jpg
# 82, 24, ./DATA/TRAIN_mini/FRONTTATEFITTOP/ca0ce270897f4d5eac011077ce792019d24e4edc_R180_B2T_RESIZED.jpg
# 83, 24, ./DATA/TRAIN_mini/FRONTTATEFITTOP/ad0b9726bc7bb532faa8ea8f8d22255cc06761d9_R180_B2T_RESIZED.jpg
# 84, 24, ./DATA/TRAIN_mini/00661_Person_resized/65534555_ea7f59eb05_z.jpg.jpg
# 85, 24, ./DATA/TRAIN_mini/00661_Person_resized/4359717403_2dcf627bb5_z.jpg.jpg
# 86, 24, ./DATA/TRAIN_mini/00661_Person_resized/455179640_df21522f28_z.jpg.jpg
# 87, 24, ./DATA/TRAIN_mini/00661_Person_resized/8720604803_ee26cd3991_z.jpg.jpg
# 88, 24, ./DATA/TRAIN_mini/01248_Snack_resized/7742757782_867cdff91c_z.jpg.jpg
# 89, 24, ./DATA/TRAIN_mini/01248_Snack_resized/5986550331_99572050ff_z.jpg.jpg
# 90, 24, ./DATA/TRAIN_mini/01248_Snack_resized/6617371643_c267539cd8_z.jpg.jpg
# 91, 24, ./DATA/TRAIN_mini/01248_Snack_resized/4090417749_9e09f74975_z.jpg.jpg
# 92, 24, ./DATA/TRAIN_mini/FRONTTATEFITLEFT/f2f14c70fa19c7300396ad60e342b6eb1bafbc5f_224_70.jpg
# 93, 24, ./DATA/TRAIN_mini/FRONTTATEFITLEFT/1d84c5d3e379eed92c9c07aa1d564db5f6a19b1d_R180_R2L_RESIZED.jpg
# 94, 24, ./DATA/TRAIN_mini/FRONTTATEFITLEFT/350fbf85803b44fd1de6bdd5daf3e940578e7f92_TLC_RESIZED.jpg
# 95, 24, ./DATA/TRAIN_mini/FRONTTATEFITLEFT/9a52eb54099379f928672e0032f5f93133b6ad2f_R180_R2L_RESIZED.jpg
# 96, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEFITBOTTOM/2053f7dd2432d1820c59e0799c722228ccf42806_224_70.jpg
# 97, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEFITBOTTOM/4f7d34d22bab666fdbf67978ab0fd224c51f111a_224_70.jpg
# 98, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEF
# 171, 24, ./DATA/TRAIN_mini/00915_Traffic_sign_resized/5278307080_2fb0bb0100_z.jpg.jpg
# 172, 24, ./DATA/TRAIN_mini/FRONTTATEFITBOTTOM/96ec4137d4564725af6f33473b1780317c60ef16_224_70.jpg
# 173, 24, ./DATA/TRAIN_mini/FRONTTATEFITBOTTOM/0736f6dc1544b8c60de95392f79d94acc577843f_224_70.jpg
# 174, 24, ./DATA/TRAIN_mini/FRONTTATEFITBOTTOM/6f0d7488f77b2692d1ab256a4a2c5b2f64eeedaf_224_70.jpg
# 175, 24, ./DATA/TRAIN_mini/FRONTTATEFITBOTTOM/ad7524bb7d6088454fb835fd53ab30f2efa63bce_224_70.jpg
# 176, 24, ./DATA/TRAIN_mini/02773_Jacket_resized/1312692373_0c7a6aebd7_o.jpg.jpg
# 177, 24, ./DATA/TRAIN_mini/02773_Jacket_resized/9042982342_c91b00d515_z.jpg.jpg
# 178, 24, ./DATA/TRAIN_mini/02773_Jacket_resized/3194406516_0cd001c4d1_z.jpg?zz=1.jpg
# 179, 24, ./DATA/TRAIN_mini/02773_Jacket_resized/53070560_011e191542_z.jpg.jpg
# 180, 24, ./DATA/TRAIN_mini/03276_Human_hair_resized/10031042924_ca02b9fa67_z.jpg.jpg
# 181, 24, ./DATA/TRAIN_mini/03276_Human_hair_resized/4839635172_08326c4edd_z.jpg.jpg
# 182, 24, ./DATA/TRAIN_mini/03276_Human_hair_resized/244319738_f068e20a05_z.jpg.jpg
# 183, 24, ./DATA/TRAIN_mini/03276_Human_hair_resized/5339079908_201665a3f4_z.jpg.jpg
# 184, 24, ./DATA/TRAIN_mini/FRONTNANAMEFIT/c5e95b42b676034761479d4d5acb994b975b95e5_R90_R20_NCC50_RESIZED.jpg
# 185, 24, ./DATA/TRAIN_mini/FRONTNANAMEFIT/3e55bdcb7d737ff4b2527568b65b82860ffd3233_R90_R20_NCC40_RESIZED.jpg
# 186, 24, ./DATA/TRAIN_mini/FRONTNANAMEFIT/bf78aba25a68b8d4932536f9e456a45c45060a68_R90_R45_NCC40_RESIZED.jpg
# 187, 24, ./DATA/TRAIN_mini/FRONTNANAMEFIT/8a8a0d28a89d19949143002cd4c119aa7a099196_R290_NCC40_RESIZED.jpg
# 188, 24, ./DATA/TRAIN_mini/03255_Bicycle_helmet_resized/14985757289_34fd6749fb_z.jpg.jpg
# 189, 24, ./DATA/TRAIN_mini/03255_Bicycle_helmet_resized/7871357316_ea40a646aa_z.jpg.jpg
# 190, 24, ./DATA/TRAIN_mini/03255_Bicycle_helmet_resized/3577686260_1f18060e83_z.jpg?zz=1.jpg
# 191, 24, ./DATA/TRAIN_mini/03255_Bicycle_helmet_resized/3549071855_0dd375256f_z.jpg.jpg
# 192, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEFITCENTER/3ae578e4aacab89c22be253d765b7593f4cb3139_224_70.jpg
# 193, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEFITCENTER/c13793740640970c8e9a32b212d5fa395c508d4d_224_70.jpg
# 194, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEFITCENTER/9231380c096e0a0b57c35d180e6152d5bad48482_224_70.jpg
# 195, 24, ./DATA/TRAIN_mini/WINTERFRONTTATEFITCENTER/2a7b38b234e7caeefa521b95982260172e283737_224_70.jpg
# 196, 24, ./DATA/TRAIN_mini/WINTERFRONTYOKOFAR/aa5504d89d971d0c4cc51cff14052d9cedb0e748_R90_RESIZED.jpg
# 197, 24, ./DATA/TRAIN_mini/WINTERFRONTYOKOFAR/60eb88788035790a737d97f4b6740369de401e2c_R90_RESIZED.jpg
# 198, 24, ./DATA/TRAIN_mini/WINTERFRONTYOKOFAR/154c54efd02941f3a42bd5b00a22f2c123feedeb.jpg
# 199, 24, ./DATA/TRAIN_mini/WINTERFRONTYOKOFAR/4381724965519aafd713bdb68a84636c7979e48d.jpg
# 200, 24, ./DATA/TRAIN_mini/00837_Billboard_resized/3040334370_83ea207743_z.jpg.jpg
# 201, 24, ./DATA/TRAIN_mini/00837_Billboard_resized/6183020351_9265f92f26_z.jpg.jpg
# 202, 24, ./DATA/TRAIN_mini/00837_Billboard_resized/4124691362_b0768f39cf_z.jpg.jpg
# 203, 24, ./DATA/TRAIN_mini/00837_Billboard_resized/15063843400_d680fde237_z.jpg.jpg
# 204, 24, ./DATA/TRAIN_mini/06049_Human_face_resized/15606295738_d10a02f91f_z.jpg.jpg
# 205, 24, ./DATA/TRAIN_mini/06049_Human_face_resized/16658332588_2b64a9ed9b_z.jpg.jpg
# 206, 24, ./DATA/TRAIN_mini/06049_Human_face_resized/6195210110_0e2072ca40_z.jpg.jpg
# 207, 24, ./DATA/TRAIN_mini/06049_Human_face_resized/974230107_3a1db4732a_z.jpg.jpg

# %%
# train the neural network
epochs = 10
for e in range(epochs):
    for record in train_dataset:
        inputs = numpy.asfarray(record[1:])
        # print(inputs)
        targets = numpy.zeros(output_nodes) + 0.01
        targets[int(record[0])] = 0.99
        # print(targets)
        n.train(inputs, targets)
        pass
    pass

# %%
# create test dataset
items = 52
test_dataset = []
fig = matplotlib.pyplot.figure(figsize=(20, items * 2))
for image_file_name in glob.glob('./DATA/TEST_mini/*/*'):
    # print(image_file_name)
    line = str(image_file_name[17:])
    line = line[:line.find('/')]
    # print(line)
    if line  == "FRONTNANAMEFIT": label = 0
    elif line  == "FRONTTATEFAR": label = 1
    elif line  == "FRONTTATEFITBOTTOM": label = 2
    elif line  == "FRONTTATEFITCENTER": label = 3
    elif line  == "FRONTTATEFITLEFT": label = 4
    elif line  == "FRONTTATEFITRIGHT": label = 5
    elif line  == "FRONTTATEFITTOP": label = 6
    elif line  == "FRONTTATEJUSTCENTER": label = 7
    elif line  == "FRONTTATENEAR": label = 8
    elif line  == "FRONTYOKOFAR": label = 9
    elif line  == "FRONTYOKOFIT": label = 10
    elif line  == "NANAMETATEFIT": label = 11
    elif line  == "WINTERFRONTNANAMEFIT": label = 12
    elif line  == "WINTERFRONTTATEFAR": label = 13
    elif line  == "WINTERFRONTTATEFITBOTTOM": label = 14
    elif line  == "WINTERFRONTTATEFITCENTER": label = 15
    elif line  == "WINTERFRONTTATEFITLEFT": label = 16
    elif line  == "WINTERFRONTTATEFITRIGHT": label = 17
    elif line  == "WINTERFRONTTATEFITTOP": label = 18
    elif line  == "WINTERFRONTTATEJUSTCENTER": label = 19
    elif line  == "WINTERFRONTTATENEAR": label = 20
    elif line  == "WINTERFRONTYOKOFAR": label = 21
    elif line  == "WINTERFRONTYOKOFIT": label = 22
    elif line  == "WINTERNANAMETATEFIT": label = 23
    else: label = 24
    # print(label)
    img = transform.resize(io.imread(image_file_name, as_gray=True), (28, 28), mode='symmetric', preserve_range=True)
    
    
    # matplotlib.pyplot.imshow(img, cmap='Greys', interpolation='None')
    ax = fig.add_subplot(20, 5, len(test_dataset) + 1)
    ax.imshow(img,  cmap='Greys', interpolation='None')
    ax.set_axis_off()
    ax.set_title(str(len(test_dataset)))
    img_data = img.reshape(784)
    img_data = (img_data / 255.0 * 0.99) + 0.01
    # print(numpy.min(img_data))
    # print(numpy.max(img_data))
    record = numpy.append(label,img_data)
    # print(record)
    test_dataset.append(record)
    print(str(len(test_dataset) - 1) + ", " + str(label) +", " + image_file_name) 
    pass
matplotlib.pyplot.show()
# Out:
# 0, 24, ./DATA/TEST_mini/02838_Human_leg_resized/9398240723_e7a663b2a7_z.jpg.jpg
# 1, 24, ./DATA/TEST_mini/00486_Bicycle_wheel_resized/15297068702_d17fc2cb2e_z.jpg.jpg
# 2, 3, ./DATA/TEST_mini/FRONTTATEFITCENTER/bed0944491a8c177de720b0f704f3e8ef793e09b_224_70.jpg
# 3, 11, ./DATA/TEST_mini/NANAMETATEFIT/a681c5c9f30b8e26be1e969197d946d22bb335d5_224_70.jpg
# 4, 13, ./DATA/TEST_mini/WINTERFRONTTATEFAR/9e17de620cefc76c96a7b9ced76b45815daf9203.jpg
# 5, 24, ./DATA/TEST_mini/00479_Boy_resized/156039810_b2d4143515_o.jpg.jpg
# 6, 22, ./DATA/TEST_mini/WINTERFRONTYOKOFIT/eb84c58b3775b56b2a702c964c929a4a291024b1_R180_B2T_RESIZED_R90.jpg
# 7, 24, ./DATA/TEST_mini/01318_Desk_resized/2552258919_8e7a4a866a_z.jpg.jpg
# 8, 20, ./DATA/TEST_mini/WINTERFRONTTATENEAR/f99ba707a1e7005f2a519a75c5e84f0f1e9c01d8_TRIMMED_WINTER_JCC60_RESIZED.jpg
# 9, 24, ./DATA/TEST_mini/02648_Fruit_resized/19879103843_dc9775df76_z.jpg.jpg
# 10, 24, ./DATA/TEST_mini/06052_Human_arm_resized/15193350585_1a90948d95_z.jpg.jpg
# 11, 8, ./DATA/TEST_mini/FRONTTATENEAR/4144356c77490b6a4c28894737f3226b435c3e54_224_70.jpg
# 12, 18, ./DATA/TEST_mini/WINTERFRONTTATEFITTOP/ecda0111255c6fa4b42356fd4829483e6f1f862c_R180_B2T_RESIZED.jpg
# 13, 24, ./DATA/TEST_mini/00109_Toy_resized/22112582188_31c4316a7c_z.jpg.jpg
# 14, 23, ./DATA/TEST_mini/WINTERNANAMETATEFIT/29034fcd443400c739481bb8aea659e4b1ea6c6b_224_70.jpg
# 15, 24, ./DATA/TEST_mini/00160_Human_eye_resized/16073609022_81e249b5e6_z.jpg.jpg
# 16, 24, ./DATA/TEST_mini/03890_Motorcycle_resized/6828159206_267b0b87c7_z.jpg.jpg
# 17, 24, ./DATA/TEST_mini/02227_Human_body_resized/8437182767_ff6358cd48_z.jpg.jpg
# 18, 10, ./DATA/TEST_mini/FRONTYOKOFIT/bce66f5d82f99ddc01fb360b56c9cf5ce3a03be8_R180_B2T_RESIZED_R90.jpg
# 19, 1, ./DATA/TEST_mini/FRONTTATEFAR/6dbe6b2768a0374fb38194cce5bec1573f1c1342_224_70.jpg
# 20, 6, ./DATA/TEST_mini/FRONTTATEFITTOP/fe51a20d5265c2cef47dbe1cdeeef5baafedb83a_224_70.jpg
# 21, 24, ./DATA/TEST_mini/00661_Person_resized/8227478572_2220682e94_z.jpg.jpg
# 22, 24, ./DATA/TEST_mini/01248_Snack_resized/5524737832_54957b0238_z.jpg.jpg
# 23, 4, ./DATA/TEST_mini/FRONTTATEFITLEFT/b5cdfb33d789d668fd02f6aae9b5c04b99e6c977_224_70.jpg
# 24, 14, ./DATA/TEST_mini/WINTERFRONTTATEFITBOTTOM/e7ae5138242293fd63a9f381e185b82b0c0e5c42_224_70.jpg
# 25, 24, ./DATA/TEST_mini/00195_Human_beard_resized/4279415424_7fc2b64d36_z.jpg.jpg
# 26, 24, ./DATA/TEST_mini/00318_Sunglasses_resized/14362229342_f4f31183ac_z.jpg.jpg
# 27, 16, ./DATA/TEST_mini/WINTERFRONTTATEFITLEFT/cf8aa4b6ff80e52064c67bf30fd19429ae44303f_TLC_RESIZED.jpg
# 28, 24, ./DATA/TEST_mini/02921_Human_ear_resized/8650410154_6c676114ce_z.jpg.jpg
# 29, 12, ./DATA/TEST_mini/WINTERFRONTNANAMEFIT/b149ab63a8fa7015d96913e15264c1b191e42393_R70_NCC50_RESIZED.jpg
# 30, 7, ./DATA/TEST_mini/FRONTTATEJUSTCENTER/dd111d72824bfceb9985a0ca03181f63cbe4a84e_R90_TCC60_RESIZED.jpg
# 31, 24, ./DATA/TEST_mini/00784_Vehicle_registration_plate_resized/16932954570_f3f88e4313_z.jpg.jpg
# 32, 24, ./DATA/TEST_mini/06008_Camera_resized/105069656_651655e379_z.jpg.jpg
# 33, 24, ./DATA/TEST_mini/06805_Human_nose_resized/5714933194_b14ab7071b_z.jpg.jpg
# 34, 19, ./DATA/TEST_mini/WINTERFRONTTATEJUSTCENTER/be34cc9c0ce1bbbb5c98fff253d8f0171747bdd7_KRD_TRIMMED_RESIZED.jpg
# 35, 17, ./DATA/TEST_mini/WINTERFRONTTATEFITRIGHT/3e07e626930a5f2731d45ce80a1bbd23d287b0c4_R90_TRC_RESIZED.jpg
# 36, 24, ./DATA/TEST_mini/03968_Man_resized/14563361322_9668791f8e_z.jpg.jpg
# 37, 24, ./DATA/TEST_mini/02807_Street_light_resized/2527575615_17d1e2eb82_z.jpg.jpg
# 38, 24, ./DATA/TEST_mini/02943_Woman_resized/2070618_e39c06d281_z.jpg?zz=1.jpg
# 39, 9, ./DATA/TEST_mini/FRONTYOKOFAR/44dbb16027e95c6bf49eacf415e53676f3439fe8_224_70.jpg
# 40, 24, ./DATA/TEST_mini/01558_Box_resized/6909788327_f973461560_z.jpg.jpg
# 41, 5, ./DATA/TEST_mini/FRONTTATEFITRIGHT/f0065648c742073bc09be173698e4ce5263394b6_TRC_RESIZED.jpg
# 42, 24, ./DATA/TEST_mini/00915_Traffic_sign_resized/4196293421_0b79504f9c_z.jpg.jpg
# 43, 2, ./DATA/TEST_mini/FRONTTATEFITBOTTOM/8759f3f419482270c6a3ec95c9652efe3e04da6b_224_70.jpg
# 44, 24, ./DATA/TEST_mini/02773_Jacket_resized/7874449568_2925b7b158_z.jpg.jpg
# 45, 24, ./DATA/TEST_mini/03276_Human_hair_resized/5027706707_eb7d59ba83_z.jpg.jpg
# 46, 0, ./DATA/TEST_mini/FRONTNANAMEFIT/ba1f23d9807b01160012766c80ffc61b0020129c_R90_R340_NCC50_RESIZED.jpg
# 47, 24, ./DATA/TEST_mini/03255_Bicycle_helmet_resized/2384343876_35e565cb0c_z.jpg?zz=1.jpg
# 48, 15, ./DATA/TEST_mini/WINTERFRONTTATEFITCENTER/c3ec3dd0a38f726bbb8afa675a3a03e6f8f1709a_224_70.jpg
# 49, 21, ./DATA/TEST_mini/WINTERFRONTYOKOFAR/87c4fe2e56492b1fbe2f9f71ea63447a33ab1903_224_70.jpg
# 50, 24, ./DATA/TEST_mini/00837_Billboard_resized/5706905979_3bf1bb737e_z.jpg.jpg
# 51, 24, ./DATA/TEST_mini/06049_Human_face_resized/15852626318_2b7a4de6b4_z.jpg.jpg

# %%
# test the neural network with our own images
item = 49
matplotlib.pyplot.imshow(test_dataset[item][1:].reshape(28,28), cmap='Greys', interpolation='None')
correct_label = test_dataset[item][0]
print(correct_label)
inputs = test_dataset[item][1:]
outputs = n.query(inputs)
print (outputs)
label = numpy.argmax(outputs)
print("network says ", label)
if (label == correct_label):
    print ("match!")
else:
    print ("no match!")
    pass
# Out:
# 21.0
# [[0.01159945]
#  [0.01159009]
#  [0.01158643]
#  [0.01158553]
#  [0.01158894]
#  [0.01156347]
#  [0.011601  ]
#  [0.01158742]
#  [0.0115979 ]
#  [0.01156373]
#  [0.01157758]
#  [0.01158889]
#  [0.01159058]
#  [0.01158036]
#  [0.01159768]
#  [0.01158349]
#  [0.01159833]
#  [0.01157591]
#  [0.01159257]
#  [0.01158352]
#  [0.01159724]
#  [0.01159367]
#  [0.01158555]
#  [0.01158763]
#  [0.98841204]]
# network says  24
# no match!

# %%
# test the neural network
scorecard = []
for record in test_dataset:
    # print(record)
    correct_label = int(record[0])
    inputs = test_dataset[item][1:]
    outputs = n.query(inputs)
    label = numpy.argmax(outputs)
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    pass
scorecard_array = numpy.asarray(scorecard)
print ("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.5384615384615384
